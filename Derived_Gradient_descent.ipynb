# %% [markdown]
# # Gradient Descent Derived

# %%
import numpy as np 
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
x,y = make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [37.18885209]
# 0.8312487445619918

# %%
class MyGradientDescent:
    def __init__(self,learning_rate,epochs):
        self.b = 100
        self.m = -100 
        self.lr = learning_rate
        self.epochs = epochs   

    def fit(self , x , y):
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*x.ravel()-self.b)

            loss_slope_m = -2 * np.sum(y - self.m*x.ravel()-self.b)*x.ravel()

            self.b = self.b - self.lr*loss_slope_b
            self.m = self.m - self.lr*loss_slope_m

    def predict(self, x):
        return self.m * x - self.b

# %%
derived_gd = MyGradientDescent(0.001,100)

# %%
derived_gd.fit(x,y)

# %%
derived_gd.predict(x)
# Out:
# array([[-5.54101625e+01, -5.81908562e+01, -5.69322879e+01, ...,
#         -5.00855777e+01, -5.15846125e+01, -5.30000065e+01],
#        [-1.33334839e+02, -1.65462866e+02, -1.50921417e+02, ...,
#         -7.18147936e+01, -8.91345834e+01, -1.05487991e+02],
#        [-9.80653924e+01, -1.16910538e+02, -1.08381047e+02, ...,
#         -6.19799447e+01, -7.21391109e+01, -8.17314318e+01],
#        ...,
#        [ 9.38031628e+01,  1.47217930e+02,  1.23041900e+02, ...,
#         -8.47759547e+00,  2.03175918e+01,  4.75061099e+01],
#        [ 5.17950108e+01,  8.93890230e+01,  7.23736169e+01, ...,
#         -2.01915254e+01,  7.49041861e-02,  1.92105391e+01],
#        [ 1.21307643e+01,  3.47867633e+01,  2.45324436e+01, ...,
#         -3.12518598e+01, -1.90383134e+01, -7.50623951e+00]])
